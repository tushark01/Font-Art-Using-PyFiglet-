# %%
pip install pyfiglet
# Out:
# ...
#      |████████████████████████████████| 865 kB 15.2 MB/s
# ...

# %%
import pyfiglet
font = pyfiglet.figlet_format("Tushar Khete")
print(font)
# Out:
#  _____          _                  _  ___          _
# |_   _|   _ ___| |__   __ _ _ __  | |/ / |__   ___| |_ ___
#   | || | | / __| '_ \ / _` | '__| | ' /| '_ \ / _ \ __/ _ \
#   | || |_| \__ \ | | | (_| | |    | . \| | | |  __/ ||  __/
#   |_| \__,_|___/_| |_|\__,_|_|    |_|\_\_| |_|\___|\__\___|
